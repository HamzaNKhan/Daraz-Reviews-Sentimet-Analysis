# %%
vowels = ['a','e','i','o','u']
Name = 'Hamza Nadeeem'
ModifiedName = ''
for i in (Name):
    if i in vowels:
        continue
    ModifiedName+=i
print(Name)
print(ModifiedName)
# Out:
# Hamza Nadeeem
# Hmz Ndm

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import time
from selenium.webdriver.chrome.options import Options
import pandas as pd

# %%
# Getting the landing page after searching 'skin care' product.
url = "https://www.daraz.pk/catalog/?q=skin+care&_keyori=ss&from=input&spm=a2a0e.searchlist.search.go.3e7150f6yp46bT"
driver = webdriver.Chrome()
driver.get(url)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
time.sleep(10)
driver.quit()

# %%
df_daraz = pd.DataFrame(columns = ['Product', 'Review'])
# df_daraz.reset_index(inplace = True)
-
# Getting Each product one by one 
products = soup.find_all('div' , {'class' : 'c2prKC'})
# reviewList = list()
# i=0
for product in products:
#     i+=1
#     if i==4: 
#         print("BROKE!!!!!!!")
#         break
    
    Extracting Name and link of product
    Name = product.find('div' , {'class': 'c16H9d'}).text
    link = product.find("a").get('href')
#     print('https:'+link)

#     Opening product's link for reviews retreival
    browser = webdriver.Chrome()
    browser.get('https:'+ link)
    time.sleep(12)
    
    print('\nProduct Name:',Name, '\nReviews:')
    
#     while loop is used to get all the reviews from pagination 
    while True:
        html = browser.page_source
        product_page = BeautifulSoup(html, 'html.parser')
        reviewsTag =  product_page.find_all('div', {'class':'item'})
    #     print('reviewtag' , reviewsTag)
    #     print(product_page.prettify())
    
#     'reviews' hold the HTML of review portion of the page
        reviews = reviewsTag if reviewsTag else "NA"
        if reviews == 'NA':
            print('\nNo review found')
            break
        
#       variable 'review' will iterate and get each review  
        for review in reviews:
            
            reviewText = review.find('div', {'class' : 'content'}).text 
    #         print(review)
    #         reviewList.append(reviewText)
            to_append = [Name, reviewText]
            print('=>', reviewText)
    #         print(to_append)
            
            
#             Stroing reviews into dataframe with there respective product

            df_length = len(df_daraz)
            df_daraz.loc[df_length] = to_append
        
#       getting Xpath of pagination 'Next' button and clicking it 

        try:
            if(browser.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[2]/div/button[2]').is_enabled()):
    #             browser.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[2]/div/button[2]').click()

                button = browser.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[2]/div/button[2]')
                browser.execute_script("arguments[0].click();", button)
                time.sleep(5)
            else:
                break
        except:
            break
#     ////////////// while loop ends
     
    browser.quit()
# Out:
# Product Name: Light 3 in 1 Face Wash, Scrub and Mask - 100 ml
# Reviews:
# => ver good product in low price and sealed pack.
# Seller Recommended💕
# => same as pic in this price it is good and delivered in time baki result to thori der use karnay k bad pata chlay ga overall it is 👍
# => bohat hi kamal ki cream hai i love it itni km price mai to boht hi zabardast hai highly recommended ❤😍love this product
# => good product
# => Quality is good in this buying amount
# => ye france ki h ? mjhe pata nh tha mene order ker di lekin use nh ker sakti
# => tell me plz it's a face wash I received my  order  good quantity
#
# => thnks alot... bht aachi cream. hha.
# => Nice Product. Recommend.
# => thee tha itni price ma
# =>
# =>
# =>
# =>
#
# Product Name: World's Best Original Dew Herbal Ultra Whitening Skin Polish Bleach 100% Result
# Reviews:
# => Booster or powder dono bottle me kam thy.. 😒
# => thank you 💞💞 daraz fast delivery and parcel same as shown
# => amazing & original product with excellent results
# => result is good will buy it again
# => Ye waisa nhe jaisa suna tha
# => nice hain
# =>
# =>
# =>
# =>
# =>
#
# Product Name: Silicone Beauty Wash pad Face Blackhead Facial Cleansing Brush Facial Massage
# Reviews:
# => It's really  great thing that sponge is very soft and squishy. It's an average SpongeBob which  is well usable for the face easily. Thanks will shop again.
# => This massager is very good..
# Though very small in size but excellent in work.
# satisfied completely
# 💯 recommended...
# good quality as well
# => OMG... these are much better than i was expecting... really good.... actually happy to get them
# => Its good, soft enough.i recommend others too but Me ny miniso ka use kia tha pehly Wo zydah acha hay more soft than this one.miniso walay k agay say brush tooths b lambay hain or more flexible than this..
# Yeh b acha hay 95/100 ♥.
# Recommended ❤️
# Jazak Allah ♥
# => Just the right size, feels invigorating, and came in my favourite colour! Very happy!
# => same as shown and very soft
# => Although it is small but it's really nice.
# => Same as picture.
# Loved it.
# => super sey bi oper 👍
# => Good ✔️💯
# => i ordered and recieved two! the packaing was not the best quality but the product was amazing i loved it and I've been using it for the past 3 days believe me when i say my skin has gotten softer i loved the product,would recommend
# => 😁😁😁It's very chotu but good product I like it and delivery on time seller is cooperative thanks daraz
# => zaberdast ha ...... face ko achi tarha cleansing krta han .. or price b low han
# => The product is really good and the package came before time. Happy customer.
# => got my stuffs same as shown in pics
# thnku seller
# => same as shown.  genuine product keep it up ☺️☺️
# => its so soft......easy to use....gentle for face
# => Awesome soft and very effective product
# => Very very nice..thankyou daraz....
# => its good.. product is as explained
# => Good😊 but it was very small 😢
# => Very small but good
# => not bad but not good
# => good hai GG👍👍👍
# => Received like img
# => bus teehk tha
# => Nice product
# => nyc product
# => very good
# => useful
# => good
# => nice
# => good
# =>
# =>
# =>
# =>
# =>
# =>
# =>
#
# Product Name: Mec Whitening Activated Charcoal Face Wash
# Reviews:
# => Thanks daraz i again buy 2 more face washes because it’s too good and it’s suitable for my skin and i also like daraz services they upgrade their services day by day keep it up it will increase your customers and customer,s trust 👍
# => This product is awesome yrrr pehli wash me he bht zabrdast feeling ati hai price bhi bhht munasib hai es product ki but price k hisab sy product bhhht zabrdast hai specially oily skin k liye great experience keep it up dear daraz👍
# => very nice kamal ka face wash he yar pehli dafa e face glow kiya or soft I like it sab ek bar try kro inahALLAH pasnd ay ga
# => its awesome maked my skin soft.
# => i love it 😍 its good deal
# => Good Product..
# => this is very good product feeling fresh once I washed
# => acha hai good
# => Best product h 👌
# => thanks
# => I liked this product. It was original. The bottle and print is good quality and the product is high quality. The consistency of the product is really very good and it has small beads... the smell is fresh and leaves a little cooling effect ... The results are awesome removes dirt and pollution deep ... I can call this product to be addictive... Really good ... recommended 👍🏻
# => This face wash is same as picture and this result is very good its cannot damage our skin
# => sir unbelievable  awesome results thank you ❤❤❤❤❤
# => I have ordered  charcoal facewash and you havery send floral one😡
# => amazing  product i love the quality thanks daraz and seller 😇❤
# => it's so good recommend to buy this
# => satisfied....thanks
# => boht hi acha h....fres ho gy skin.recomended
# => its make my face so soft and clear..👍👍👍
# => out class KIA zabardast face wash hay
# => waooo nice product & delivery on time
# => good quality product
# => Nice face wash.
# => ex cellent
# => GOOD ONE..
# =>  very good
# => Amazing
# => good
# => good
# =>
# =>
# =>
# =>
# =>
# =>
# =>
# =>
# =>
#
# Product Name: Pack Of 2 Herbals Double Action Cleanser Cream & Herbals Skin Polish Cream 300 ML
# Reviews:
# => great packaging and amazing product at low price
# => excellent 👌 product i will shop again
# => I love it 💕 and packing also good
# => great product 👍
# =>
# =>
#
# Product Name: BIOAQUA Face Skin Care Acne Anti-Wrinkle Treatment Removal Cream Spots Scar Blemish Marks
# Reviews:
#
# Product Name: BIOAQUA Face Skin Care Acne Anti-Wrinkle Treatment Removal Cream Spots Scar Blemish Marks
# Reviews:
#  No review found
#
# Product Name: Best Gold Skin Polish Set (Vol20 + Blondor 50g)
# Reviews:
# => vol20 nhi hai us ki jagah soothing hai or powder bhi quarter bottle hai
# => good product.safely packed .I recieved free gift of serum inside.giving five star.thnx
# => tamam polish ma say is ka result best ha
# => it's really awesome 😊 Kamal ka result h 10/10 from my side
# => very good 😊
# => good products bohat acha result hai but 20 vol and powder half bottle hain
# => BHT bhtvachi ha 10 minute me ITNA glowy result Mila bilkul parlour jasa
# => quantity is bit lesser...
# =>
#
# Product Name: 5 in 1 Face Massager & Cleanser - Pink
# Reviews:
#
# Product Name: 5 in 1 Face Massager & Cleanser - Pink
# Reviews:
#  No review found
#
# Product Name: One Spring Pink Gel Cream - 30M
# Reviews:
#
# Product Name: One Spring Pink Gel Cream - 30M
# Reviews:
#  No review found
#
# Product Name: Oriflame Pure Skin Scrub & Mask | Sstore | Sadaf Store Sstore
# Reviews:
# => best
#
# Product Name: Pure Skin 2 in 1 Face Wash And Scrub 150ml
# Reviews:
# => i received my order with original product and best quality.
# => awesome and perfect packing.❤️
# => Nice product
#
# Product Name: MUICIN - Vitamin C Face Wash - 100g
# Reviews:
#
# Product Name: MUICIN - Vitamin C Face Wash - 100g
# Reviews:
#  No review found
#
# Product Name: BIOAQUA Pure Skin Anti Acne Removal Face Care Treatment Set Acne Serum Acne Cream and Acne Cleanser
# Reviews:
# => same as pic good products
#
# Product Name: New Dr.R Skin White Face Wash
# Reviews:
# => nice product 👍👍  but ....very bad packing im very dissapointed adha face wash mila hai adah gir kar aya hai.... but product is very good...dilevery bbhi time par hoi hai.....good job....😊
# => buhat acha hai mujah buhat pasand a yah hai but ap k deliver boy zada payse lay ty hain  384 bane hai or un ne 390 lay Kar gay
# => Disappointed ghatia product used Item bhej dia aur bottel ki nosel bhi band nahi ki leak bottel mili aur gandi bottel lag rha used product bheji  😡😡😡👎👎👎👎👎👎👎 jab k may ny kaha bhi tha
# => Amazing Product I Love it most Most of The time The sellers Send the wrong product But This Time This Seller Send Me A Orignal And Autantic Product With The Safe PAcking Thank You, Bois, I Love It Hopefully I order In Future Highly ReCommanded
# => i just love it
# => awsome ruslts
# => awsome
# =>
# =>
#
# Product Name: Dr Rashel White Skin Fade Dark Spots Whitening Face Wash Facial Cleanser Cleaner 250 ml
# Reviews:
# => bestest
# => maine bohat c product buy ki hai daraz se,,,,,,bt first time I'm disappointed,,waist of money and seller boy also a duffer guy😡
# => bht jldi dlvr hua h acha h mashaallah🙂🙂
# => bekar lg rha ha packing local ha
# => Rider gave me torn notes
# => I like your face wash
# =>
# Product Name: North For Men Subzero Soap Bar
# Reviews:
# => gud product didnt like the smell thou
#
# Product Name: Pure Skin Acne & Rejuvenation Moisturizing Mask.
# Reviews:
# => Amazing mask and really effective for acne and for best results you must use these masks twice a week after using cleanser and toner at night 👍
#
# Product Name: USA Kojic Acid WHITENING soap 50Grm (Import From Thailand)
# Reviews:
#
# Product Name: USA Kojic Acid WHITENING soap 50Grm (Import From Thailand)
# Reviews:
#  No review found
#
# Product Name: VestiGo Facial Kit 8 Piece Trial Pack
# Reviews:
# => This is so amazing I have used it I can seriously see the difference with in first use this is so good. Ny skin is so sensitive but I couldnt feel any skin ras or irritation. its good for exfoliation plus its expensive but they are giving at low price . with expiry date HIGHLY RECOMMENDED
# => Received this kit yesterday , good product in this price. Ek  bar facial kia and found it good in result
# => Received today .... well packing was good .... no damage was there ... have not use yet but overall its good in this price ... its 25ml each bottle ... its not sealed but covered with a plastic cap ....
# => BHT khush hu Mai ..ThAnks daraz..❤️❤️❤️😍💞💞😍😍😍😍😍😍😍
# => Outclass, wonderful results and amazing product. Thank you daraz
# => Alaa product ha. Best result ha, ♥ 😍 ❤ 😘 Highly recommend
# => Boh achi product hy. Herbal and safe. Result b bohat acha ha mene 2 bar use ki ha
# => It's a good product and very good result. Thanks Daraz
# => Very good result. Nice product
# => Thank you i receive  my parsol
# => very good quality
# => 0utstanding
# =>
# =>
# =>
#
# Product Name: NIVEA Refreshing Face Wash, Dry Skin, 150ml
# Reviews:
# => Delivered on time 👍
# They said in description that this is for dry skin but it is not. It's for normal skin. 😑
# => I ordered myself a dry skin face wash but received normal skin face wash instead
# => Superb face wash & delivery
# => best result
# => beset
# =>
# =>
#
# Product Name: Skin Lightening Polish Dermacoss
# Reviews:
#
# Product Name: Skin Lightening Polish Dermacoss
# Reviews:
#  No review found
#
# Product Name: Pure Active 3 in 1 Face Wash Scrub And Mask 100ml
# Reviews:
# => I am so happy with my order.thanks daraz.
# => Good as shown in picture
# => not same as original but good product
# => Lajwab.... Acha cream hy...
# =>
# =>
#
# Product Name: Olay Total Effects 7 In 1 Anti Aging Day Skin Cream+Anti Aging Cleanser Face Wash
# Reviews:
# => Original product. Thank you!
#
# Product Name: New Dr.R Vitamin C Brightening Face Wash
# Reviews:
# => wonderful ❣️❣️❣️
# it's amazing face wash
# => I am satisfied this product. Use krne me bhi bht acha hai..
# => it was amazing packing was super great jobb
#
# Product Name: 6 in 1 whitening facial kit
# Reviews:
# => zbrdst..m ne phly b uz kia h ye facial..zbrdst rzlt h..or phr se order kia...packing was good...thank u..highly recommended👍
#
# Product Name: 7 in 1 Glowing Facial kit for All skin type .
# Reviews:
# => Good product thank you daraz ❤️
#
# Product Name: Bio AQUA Pure Skin Anti Acne-Light Print & Cleanser
# Reviews:
#
# Product Name: Bio AQUA Pure Skin Anti Acne-Light Print & Cleanser
# Reviews:
#  No review found
#
# Product Name: USA Beauty Care Face out for Black Spot Whitening Soap Imported From Thiland
# Reviews:
# => works well on skin and also has antiseptic and antibacterial effects.fruity fragrance.same as shown in picture.
# => بہترین پروڈکٹ شکریہ بھائی جان ۔۔۔ ❤❤❤❤❤👍
# => Original product, perfect results, timely delivered. Fully satisfied
# => awesome 😊 soap
#
# Product Name: Pure Active 3 in 1 Face Wash Scrub And Mask - 60 ml
# Reviews:
# => Haven't used it yet but product looks original and packaging was done nicely
# => look not original, service was good, don't but it plz
# => good product
# => same as shown in a pic deliver on time bht achi chz hai relxing highly recmnded thanks daraz
# => it's is so good I don't know original Hy k Nhi Hy results kamal k hy
# => Good but small
# => good acha gain
# =>
# =>
# =>
# =>
#
# Product Name: Biocos Whitening Soap
# Reviews:
# => best product  delivery on time thank you  daraz
# => very good results
# amazing product.will order again inshallah
# => it excellent
#
# Product Name: 3Pcs Gloden Mask Special Offer For Product Peel Off Facial Mask
# Reviews:
#
# Product Name: 3Pcs Gloden Mask Special Offer For Product Peel Off Facial Mask
# Reviews:
#  No review found
#
# Product Name: Mec Whitening Face Wash (Pack of 2) 100gm Flawless White, Acne Clean
# Reviews:
# => packing was very good......and the product is same as shown in pictures...... satisfied!!👍🏻👍🏻
# => perfectly packed 👍 Good product 👌👌Recommended ✔️✔️
# => highly satisfied with the product... will shop again INSHAHALLAH... Thank you 💕
# => parsal  mill gaya ha lakin  dono 1 hi bhaj dia  ha  1 Acne clean  aor2 whitening face wash  tha  lakin dono yahi bhaj  dia ha mana order  karna sa  phala hi pucha  tha  same  hi  ho  gaya jo  pictures  ma  ha ab product  to achi hi lag  rHi  ha I want  change 1
# => its like my 3rd order and mec products and the best
# my skin got way better after using thanks mec 🤩❤
# => deal me 2 face washthe bheja ek jab payment poori li hai toh cheez bhi poori bheja karo
# return karo ya dusra face wash bhejo
# disappointed
# => fast delivery n good packaging .. satisfied🌼 ab use ka bad result ptw chlna kesa hope so..  acne kam hu jaye !
# => The product is best and the seller delivered it before the given time period.
# => I am so satisfied with these face washes.. Just buy it guyz🤩
# => Highly Satisfied❤️
# => 👍🏻
# => very good service best abd such a cooperative seller  and charchol facewash is just wow.. recommended
# => i'm using this face wash i heard too much about mec hope so it will work good on my acne scars
# => Yeah i received it safely no doubt my first and good experience with daraz app good wishes
# => awesome product👍😎 results are really amazing 😍✨
# => Both are Bomb facwashes😍highly recommended 👌
# => best product 2 time buy I like it
# => it's too goood
# => it is too good
# =>
# =>
#
# Product Name: INNISFREE - Jeju Volcanic Pore Scrub Foam 150ml
# Reviews:
#
# Product Name: INNISFREE - Jeju Volcanic Pore Scrub Foam 150ml
# Reviews:
#  No review found
#
# Product Name: Golden_ pearl double action cleanser 75ml
# Reviews:
#
# Product Name: Golden_ pearl double action cleanser 75ml
# Reviews:
#  No review found
#
# Product Name: Goodbye Dry Facial Cleansing Milk
# Reviews:
#
# Product Name: Goodbye Dry Facial Cleansing Milk
# Reviews:
#  No review found
#
# Product Name: VItamin C Kit
# Reviews:
#
# Product Name: VItamin C Kit
# Reviews:
#  No review found
#
# Product Name: Biah Gold Face Whitening Skin Polish
# Reviews:
# => ache ha per sensitiv skin k liyay
#
# Product Name: Pack Of 2 Face Wash 100 ml
# Reviews:
#
# Product Name: Pack Of 2 Face Wash 100 ml
# Reviews:
#  No review found
#
# Product Name: Derma Techno Acne Wash Soap
# Reviews:
#
# Product Name: Derma Techno Acne Wash Soap
# Reviews:
#  No review found
#
# Product Name: Acne Clear Face Wash
# Reviews:
#
# Product Name: Acne Clear Face Wash
# Reviews:
#  No review found

# %%
df_daraz
# Out:
#                                                Product  \
# 0      Light 3 in 1 Face Wash, Scrub and Mask - 100 ml
# 1      Light 3 in 1 Face Wash, Scrub and Mask - 100 ml
# 2      Light 3 in 1 Face Wash, Scrub and Mask - 100 ml
# 3      Light 3 in 1 Face Wash, Scrub and Mask - 100 ml
# 4      Light 3 in 1 Face Wash, Scrub and Mask - 100 ml
# ..                                                 ...
# 210  Mec Whitening Face Wash (Pack of 2) 100gm Flaw...
# 211  Mec Whitening Face Wash (Pack of 2) 100gm Flaw...
# 212  Mec Whitening Face Wash (Pack of 2) 100gm Flaw...
# 213  Mec Whitening Face Wash (Pack of 2) 100gm Flaw...
# 214               Biah Gold Face Whitening Skin Polish
#
#                                                 Review
# 0    ver good product in low price and sealed pack....
# 1    same as pic in this price it is good and deliv...
# 2    bohat hi kamal ki cream hai i love it itni km ...
# 3                                         good product
# 4                Quality is good in this buying amount
# ..                                                 ...
# 210                                     it's too goood
# 211                                    it is too good
# 212
# 213
# 214                  ache ha per sensitiv skin k liyay
#
# [215 rows x 2 columns]

# %%
# Removing missing values

nan_value = float("NaN")
df_daraz.replace("", nan_value, inplace=True)

df_daraz.dropna(subset = ["Review"], inplace=True)
df_daraz = df_daraz.reset_index(drop=True)

df_daraz.to_csv('ScrapedData.csv') 
df_daraz
# Out:
#                                                Product  \
# 0      Light 3 in 1 Face Wash, Scrub and Mask - 100 ml
# 1      Light 3 in 1 Face Wash, Scrub and Mask - 100 ml
# 2      Light 3 in 1 Face Wash, Scrub and Mask - 100 ml
# 3      Light 3 in 1 Face Wash, Scrub and Mask - 100 ml
# 4      Light 3 in 1 Face Wash, Scrub and Mask - 100 ml
# ..                                                 ...
# 166  Mec Whitening Face Wash (Pack of 2) 100gm Flaw...
# 167  Mec Whitening Face Wash (Pack of 2) 100gm Flaw...
# 168  Mec Whitening Face Wash (Pack of 2) 100gm Flaw...
# 169  Mec Whitening Face Wash (Pack of 2) 100gm Flaw...
# 170               Biah Gold Face Whitening Skin Polish
#
#                                                 Review
# 0    ver good product in low price and sealed pack....
# 1    same as pic in this price it is good and deliv...
# 2    bohat hi kamal ki cream hai i love it itni km ...
# 3                                         good product
# 4                Quality is good in this buying amount
# ..                                                 ...
# 166       Both are Bomb facwashes😍highly recommended 👌
# 167                 best product 2 time buy I like it
# 168                                     it's too goood
# 169                                    it is too good
# 170                  ache ha per sensitiv skin k liyay
#
# [171 rows x 2 columns]

# %%
df_daraz = pd.read_csv('ScrapedData.csv')

# %%
# Getting negative and positive words to perform sentiment analysis 
negativeWord = [line.strip() for line in open("negativeword.txt", 'r')]
positiveWord = [line.strip() for line in open("positiveword.txt", 'r')]

product = ''
reviewList = list()
reviewDict = {}
i=0

# making a dictionary where key is'product name' and value is 'prduct's reviews'
for index, row in df_daraz.iterrows():      
    if (i==0):
        product = row.Product
        i=+1
    
    if(product == row.Product):
        reviewList.append(row.Review)
    
    else:
        reviewDict[product] = reviewList
        reviewList = []
        reviewList.append(row.Review)
        product = row.Product
    
#     print(index,row)

# %%
df_semantic = pd.DataFrame(columns = ['Product', 'Sentiment'])
index=0;

# Comparing Sentiment words with the reviews of each prdoucts then saving it into dataframe 
for product in reviewDict:
#     print(reviewDict[i])
    positiveCount = 0
    negativeCount = 0
    List =  reviewDict[product]
    for listIndex in range(len(List)):
        
        for j in range(len(positiveWord) - 1):      
            if positiveWord[j] in List[listIndex]:
#                 print(positiveWord[j])
                positiveCount += 1

        for k in range(len(negativeWord) - 1):     
            if negativeWord[k] in List[listIndex]:
#                 print(negativeWord[j])
                negativeCount += 1

    if positiveCount > negativeCount:
        df_semantic.at[index,'Product'] = product
        df_semantic.at[index,'Sentiment'] = 'Postive Reviews'      
    
    elif positiveCount < negativeCount:
        df_semantic.at[index,'Product'] = product
        df_semantic.at[index,'Sentiment'] = 'Negative Reviews'
        
    elif positiveCount == negativeCount:
        df_semantic.at[index,'Product'] = product
        df_semantic.at[index,'Sentiment'] = 'Equal Feedback'
    index += 1

# %%
df_semantic.to_csv('SemanticAnalysis.csv') 
df_semantic
# Out:
#                                               Product         Sentiment
# 0     Light 3 in 1 Face Wash, Scrub and Mask - 100 ml   Postive Reviews
# 1   World's Best Original Dew Herbal Ultra Whiteni...   Postive Reviews
# 2   Silicone Beauty Wash pad Face Blackhead Facial...   Postive Reviews
# 3          Mec Whitening Activated Charcoal Face Wash   Postive Reviews
# 4   Pack Of 2 Herbals Double Action Cleanser Cream...   Postive Reviews
# 5     Best Gold Skin Polish Set (Vol20 + Blondor 50g)   Postive Reviews
# 6   Oriflame Pure Skin Scrub & Mask | Sstore | Sad...   Postive Reviews
# 7          Pure Skin 2 in 1 Face Wash And Scrub 150ml   Postive Reviews
# 8   BIOAQUA Pure Skin Anti Acne Removal Face Care ...   Postive Reviews
# 9                       New Dr.R Skin White Face Wash  Negative Reviews
# 10  Dr Rashel White Skin Fade Dark Spots Whitening...  Negative Reviews
# 11                     North For Men Subzero Soap Bar    Equal Feedback
# 12   Pure Skin Acne & Rejuvenation Moisturizing Mask.   Postive Reviews
# 13              VestiGo Facial Kit 8 Piece Trial Pack   Postive Reviews
# 14        NIVEA Refreshing Face Wash, Dry Skin, 150ml  Negative Reviews
# 15  Pure Active 3 in 1 Face Wash Scrub And Mask 100ml   Postive Reviews
# 16  Olay Total Effects 7 In 1 Anti Aging Day Skin ...    Equal Feedback
# 17           New Dr.R Vitamin C Brightening Face Wash   Postive Reviews
# 18                        6 in 1 whitening facial kit   Postive Reviews
# 19      7 in 1 Glowing Facial kit for All skin type .   Postive Reviews
# 20  USA Beauty Care Face out for Black Spot Whiten...   Postive Reviews
# 21  Pure Active 3 in 1 Face Wash Scrub And Mask - ...   Postive Reviews
# 22                              Biocos Whitening Soap   Postive Reviews
# 23  Mec Whitening Face Wash (Pack of 2) 100gm Flaw...   Postive Reviews
